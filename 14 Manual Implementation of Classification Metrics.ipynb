# %% [markdown]
# ### 14.	Manual implementation of Classification metrics

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import metrics
import pandas as pd

df = pd.read_csv('coviddata.csv')
df
# Out:
#       MEDICAL_UNIT     SEX   PATIENT_TYPE  PNEUMONIA  AGE  DIABETES  COPD  \
# 0                1  Female  Returned Home          1   65         2     2
# 1                1    Male  Returned Home          1   72         2     2
# 2                1    Male    Hosptilized          2   55         1     2
# 3                1  Female  Returned Home          2   53         2     2
# 4                1    Male  Returned Home          2   68         1     2
# ...            ...     ...            ...        ...  ...       ...   ...
# 9995             3  Female  Returned Home          2    8         2     2
# 9996             3  Female  Returned Home          2    3         2     2
# 9997             3    Male  Returned Home          2   45         2     2
# 9998             3  Female  Returned Home          2   32         2     2
# 9999             3  Female  Returned Home          2   60         2     2
#
#       ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  \
# 0          2        2             1              2               2        2
# 1          2        2             1              2               2        1
# 2          2        2             2              2               2        2
# 3          2        2             2              2               2        2
# 4          2        2             1              2               2        2
# ...      ...      ...           ...            ...             ...      ...
# 9995       2        2             2              2               2        2
# 9996       2        2             2              2               2        2
# 9997       2        2             1              2               2        2
# 9998       2        2             2              2               2        2
# 9999       2        2             2              2               2        1
#
#       RENAL_CHRONIC  TOBACCO   RESULTS
# 0                 2        2  Positive
# 1                 1        2  Negative
# 2                 2        2  Positive
# 3                 2        2  Negative
# 4                 2        2  Positive
# ...             ...      ...       ...
# 9995              2        2  Negative
# 9996              2        2  Negative
# 9997              1        2  Negative
# 9998              2        2  Negative
# 9999              2        2  Negative
#
# [10000 rows x 16 columns]

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
encoded=le.fit_transform(df['SEX'])
df.drop('SEX',axis=1,inplace=True)
df['SEX']=encoded
encoded=le.fit_transform(df['PATIENT_TYPE'])
df.drop('PATIENT_TYPE',axis=1,inplace=True)
df['PATIENT_TYPE']=encoded

# %%
x=df.drop(['RESULTS'],axis=1)
y=df['RESULTS']

X_train, X_test, y_train, y_test = train_test_split(x, y, random_state = 0, test_size=0.20)

tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
y_pred = tree.predict(X_test)

confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[0, 1])
cm_display.plot()
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
TP = confusion_matrix[1, 1]
TN = confusion_matrix[0, 0]
FP = confusion_matrix[0, 1]
FN = confusion_matrix[1, 0]

accuracy = (TP + TN) / (TP + TN + FP + FN)
precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1 = (2 * precision * recall) / (precision + recall)

print("Accuracy:", accuracy)
print("Precision:", precision)
print('Recall:', recall)
print('F1 score:', f1)
print("\nName : Dhanyatha Shree C A\nRoll No : CB.SC.I5DAS21023\n")
# Out:
# Accuracy: 0.8335
# Precision: 0.8850193477059148
# Recall: 0.9275782155272306
# F1 score: 0.9057991513437057
#
# Name : Dhanyatha Shree C A
# Roll No : CB.SC.I5DAS21023

# %%
#classification confusion matrix
df=pd.read_csv("coviddata.csv")
le=LabelEncoder()
df['SEX']=le.fit_transform(df['SEX'])
df['PATIENT_TYPE']=le.fit_transform(df['PATIENT_TYPE'])
df['RESULTS']=le.fit_transform(df['RESULTS'])

x=df.drop(['RESULTS'],axis=1)
y=df['RESULTS']

X_train, X_test, y_train, y_test = train_test_split(x, y, random_state = 0, test_size=0.20)

tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
y_pred = tree.predict(X_test)


print('accuracy of pca:',accuracy_score(ytest,ypred))

data=pd.DataFrame()
data['ytest']=y_test
data['ypred']=y_pred

TP = ((data['ytest']==1) & (data['ypred'] == 1)).sum()
TN = ((data['ytest']==0) & (data['ypred'] == 0)).sum()
FP = ((data['ytest']==0) & (data['ypred'] == 1)).sum()
FN = ((data['ytest']==1) & (data['ypred'] == 0)).sum()

print(TP,TN,FP,FN)

accuracy = (TP + TN) / (TP + TN + FP + FN)
precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1 = (2 * precision * recall) / (precision + recall)

print("Accuracy:", accuracy)
print("Precision:", precision)
print('Recall:', recall)
print('F1 score:', f1)
